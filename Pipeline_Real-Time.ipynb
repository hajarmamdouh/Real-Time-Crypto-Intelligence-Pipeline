# %%
# %pip install confluent-kafka supabase
# Out:
# Requirement already satisfied: confluent-kafka in /local_disk0/.ephemeral_nfs/envs/pythonEnv-1ac46af4-4b24-429a-b80f-1259dfa2270d/lib/python3.12/site-packages (2.13.0)
# Requirement already satisfied: supabase in /local_disk0/.ephemeral_nfs/envs/pythonEnv-1ac46af4-4b24-429a-b80f-1259dfa2270d/lib/python3.12/site-packages (2.28.0)
# Requirement already satisfied: realtime==2.28.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-1ac46af4-4b24-429a-b80f-1259dfa2270d/lib/python3.12/site-packages (from supabase) (2.28.0)
# Requirement already satisfied: supabase-functions==2.28.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-1ac46af4-4b24-429a-b80f-1259dfa2270d/lib/python3.12/site-packages (from supabase) (2.28.0)
# Requirement already satisfied: storage3==2.28.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-1ac46af4-4b24-429a-b80f-1259dfa2270d/lib/python3.12/site-packages (from supabase) (2.28.0)
# Requirement already satisfied: supabase-auth==2.28.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-1ac46af4-4b24-429a-b80f-1259dfa2270d/lib/python3.12/site-packages (from supabase) (2.28.0)
# Requirement already satisfied: postgrest==2.28.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-1ac46af4-4b24-429a-b80f-1259dfa2270d/lib/python3.12/site-packages (from supabase) (2.28.0)
# Requirement already satisfied: httpx<0.29,>=0.26 in /databricks/python3/lib/python3.12/site-packages (from supabase) (0.27.0)
# Requirement already satisfied: yarl>=1.22.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-1ac46af4-4b24-429a-b80f-1259dfa2270d/lib/python3.12/site-packages (from supabase) (1.22.0)
# Requirement already satisfied: deprecation>=2.1.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-1ac46af4-4b24-429a-b80f-1259dfa2270d/lib/python3.12/site-packages (from postgrest==2.28.0->supabase) (2.1.0)
# Requirement already satisfied: pydantic<3.0,>=1.9 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-1ac46af4-4b24-429a-b80f-1259dfa2270d/lib/python3.12/site-packages (from postgrest==2.28.0->supabase) (2.12.5)
# Requirement already satisfied: typing-extensions>=4.14.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-1ac46af4-4b24-429a-b80f-1259dfa2270d/lib/python3.12/site-packages (from realtime==2.28.0->supabase) (4.15.0)
# Requirement already satisfied: websockets<16,>=11 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-1ac46af4-4b24-429a-b80f-1259dfa2270d/lib/python3.12/site-packages (from realtime==2.28.0->supabase) (15.0.1)
# Requirement already satisfied: pyiceberg>=0.10.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-1ac46af4-4b24-429a-b80f-1259dfa2270d/lib/python3.12/site-packages (from storage3==2.28.0->supabase) (0.11.0)
# Requirement already satisfied: pyjwt>=2.10.1 in /databricks/python3/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->supabase-auth==2.28.0->supabase) (2.10.1)
# Requirement already satisfied: strenum>=0.4.15 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-1ac46af4-4b24-429a-b80f-1259dfa2270d/lib/python3.12/site-packages (from supabase-functions==2.28.0->supabase) (0.4.15)
# Requirement already satisfied: anyio in /databricks/python3/lib/python3.12/site-packages (from httpx<0.29,>=0.26->supabase) (4.6.2)
# Requirement already satisfied: certifi in /databricks/python3/lib/python3.12/site-packages (from httpx<0.29,>=0.26->supabase) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /databricks/python3/lib/python3.12/site-packages (from httpx<0.29,>=0.26->supabase) (1.0.2)
# Requirement already satisfied: idna in /databricks/python3/lib/python3.12/site-packages (from httpx<0.29,>=0.26->supabase) (3.7)
# Requirement already satisfied: sniffio in /databricks/python3/lib/python3.12/site-packages (from httpx<0.29,>=0.26->supabase) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /databricks/python3/lib/python3.12/site-packages (from httpcore==1.*->httpx<0.29,>=0.26->supabase) (0.14.0)
# Requirement already satisfied: multidict>=4.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-1ac46af4-4b24-429a-b80f-1259dfa2270d/lib/python3.12/site-packages (from yarl>=1.22.0->supabase) (6.7.1)
# Requirement already satisfied: propcache>=0.2.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-1ac46af4-4b24-429a-b80f-1259dfa2270d/lib/python3.12/site-packages (from yarl>=1.22.0->supabase) (0.4.1)
# Requirement already satisfied: packaging in /databricks/python3/lib/python3.12/site-packages (from deprecation>=2.1.0->postgrest==2.28.0->supabase) (24.1)
# Requirement already satisfied: h2<5,>=3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-1ac46af4-4b24-429a-b80f-1259dfa2270d/lib/python3.12/site-packages (from httpx[http2]<0.29,>=0.26->postgrest==2.28.0->supabase) (4.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /databricks/python3/lib/python3.12/site-packages (from pydantic<3.0,>=1.9->postgrest==2.28.0->supabase) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-1ac46af4-4b24-429a-b80f-1259dfa2270d/lib/python3.12/site-packages (from pydantic<3.0,>=1.9->postgrest==2.28.0->supabase) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-1ac46af4-4b24-429a-b80f-1259dfa2270d/lib/python3.12/site-packages (from pydantic<3.0,>=1.9->postgrest==2.28.0->supabase) (0.4.2)
# Requirement already satisfied: mmh3<6.0.0,>=4.0.0 in /databricks/python3/lib/python3.12/site-packages (from pyiceberg>=0.10.0->storage3==2.28.0->supabase) (5.1.0)
# Requirement already satisfied: requests<3.0.0,>=2.20.0 in /databricks/python3/lib/python3.12/site-packages (from pyiceberg>=0.10.0->storage3==2.28.0->supabase) (2.32.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /databricks/python3/lib/python3.12/site-packages (from pyiceberg>=0.10.0->storage3==2.28.0->supabase) (8.1.7)
# Requirement already satisfied: rich<15.0.0,>=10.11.0 in /databricks/python3/lib/python3.12/site-packages (from pyiceberg>=0.10.0->storage3==2.28.0->supabase) (13.9.4)
# Requirement already satisfied: strictyaml<2.0.0,>=1.7.0 in /databricks/python3/lib/python3.12/site-packages (from pyiceberg>=0.10.0->storage3==2.28.0->supabase) (1.7.3)
# Requirement already satisfied: fsspec>=2023.1.0 in /databricks/python3/lib/python3.12/site-packages (from pyiceberg>=0.10.0->storage3==2.28.0->supabase) (2023.5.0)
# Requirement already satisfied: pyparsing<4.0.0,>=3.1.0 in /databricks/python3/lib/python3.12/site-packages (from pyiceberg>=0.10.0->storage3==2.28.0->supabase) (3.2.0)
# Requirement already satisfied: tenacity<10.0.0,>=8.2.3 in /databricks/python3/lib/python3.12/site-packages (from pyiceberg>=0.10.0->storage3==2.28.0->supabase) (9.0.0)
# Requirement already satisfied: pyroaring<2.0.0,>=1.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-1ac46af4-4b24-429a-b80f-1259dfa2270d/lib/python3.12/site-packages (from pyiceberg>=0.10.0->storage3==2.28.0->supabase) (1.0.3)
# Requirement already satisfied: cachetools<7.0,>=5.5 in /databricks/python3/lib/python3.12/site-packages (from pyiceberg>=0.10.0->storage3==2.28.0->supabase) (5.5.1)
# Requirement already satisfied: zstandard<1.0.0,>=0.13.0 in /databricks/python3/lib/python3.12/site-packages (from pyiceberg>=0.10.0->storage3==2.28.0->supabase) (0.23.0)
# Requirement already satisfied: cryptography>=3.4.0 in /databricks/python3/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->supabase-auth==2.28.0->supabase) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /databricks/python3/lib/python3.12/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->supabase-auth==2.28.0->supabase) (1.17.1)
# Requirement already satisfied: hyperframe<7,>=6.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-1ac46af4-4b24-429a-b80f-1259dfa2270d/lib/python3.12/site-packages (from h2<5,>=3->httpx[http2]<0.29,>=0.26->postgrest==2.28.0->supabase) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-1ac46af4-4b24-429a-b80f-1259dfa2270d/lib/python3.12/site-packages (from h2<5,>=3->httpx[http2]<0.29,>=0.26->postgrest==2.28.0->supabase) (4.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /databricks/python3/lib/python3.12/site-packages (from requests<3.0.0,>=2.20.0->pyiceberg>=0.10.0->storage3==2.28.0->supabase) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /databricks/python3/lib/python3.12/site-packages (from requests<3.0.0,>=2.20.0->pyiceberg>=0.10.0->storage3==2.28.0->supabase) (2.3.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /databricks/python3/lib/python3.12/site-packages (from rich<15.0.0,>=10.11.0->pyiceberg>=0.10.0->storage3==2.28.0->supabase) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /databricks/python3/lib/python3.12/site-packages (from rich<15.0.0,>=10.11.0->pyiceberg>=0.10.0->storage3==2.28.0->supabase) (2.15.1)
# Requirement already satisfied: python-dateutil>=2.6.0 in /databricks/python3/lib/python3.12/site-packages (from strictyaml<2.0.0,>=1.7.0->pyiceberg>=0.10.0->storage3==2.28.0->supabase) (2.9.0.post0)
# Requirement already satisfied: pycparser in /databricks/python3/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->supabase-auth==2.28.0->supabase) (2.21)
# Requirement already satisfied: mdurl~=0.1 in /databricks/python3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=10.11.0->pyiceberg>=0.10.0->storage3==2.28.0->supabase) (0.1.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.6.0->strictyaml<2.0.0,>=1.7.0->pyiceberg>=0.10.0->storage3==2.28.0->supabase) (1.16.0)
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
# %sql
CREATE CATALOG IF NOT EXISTS invistis;
CREATE SCHEMA IF NOT EXISTS invistis.datalake;
CREATE VOLUME IF NOT EXISTS invistis.datalake.raw;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# -----------------------------
# Kafka Config
# -----------------------------
CONFLUENT_BOOTSTRAP = "pkc-921jm.us-east-2.aws.confluent.cloud:9092"
CONFLUENT_API_KEY   = "XGXDR43CWRIHV5HG"
CONFLUENT_SECRET    = "cflthFPYEOhMt81diPo6zq/9+MUBOyLt6oFOvvKlw0B3De42LE23KIir+Elwegdw"

CHECKPOINT_PATH = "/Volumes/invistis/datalake/raw/checkpoints"
DATA_PATH       = "/Volumes/invistis/datalake/raw/enriched"

kafka_options = {
    "kafka.bootstrap.servers": CONFLUENT_BOOTSTRAP,
    "kafka.sasl.mechanism": "PLAIN",
    "kafka.security.protocol": "SASL_SSL",
    "kafka.sasl.jaas.config": f'kafkashaded.org.apache.kafka.common.security.plain.PlainLoginModule required username="{CONFLUENT_API_KEY}" password="{CONFLUENT_SECRET}";',
    "startingOffsets": "earliest",
    "failOnDataLoss": "false"
}

print("✅ Config OK")
# Out:
# ✅ Config OK

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
# Schéma des trades
trades_schema = StructType([
    StructField("symbol", StringType()),
    StructField("price", DoubleType()),
    StructField("quantity", DoubleType()), 
    StructField("timestamp", LongType()),
    StructField("trade_id", StringType())
])

# Schéma des news
news_schema = StructType([
    StructField("title", StringType()),
    StructField("description", StringType()),
    StructField("source", StringType()),
    StructField("published_at", StringType()),
    StructField("sentiment", DoubleType())
])

# %%
trades_df = (spark.read
    .format("kafka")
    .options(**kafka_options)
    .option("subscribe", "trades_topic")
    .option("startingOffsets", "earliest")
    .load()
    .select(from_json(col("value").cast("string"), trades_schema).alias("data"))
    .select("data.*")
    .withColumn("event_time", to_timestamp(col("timestamp") / 1000))
)

print("✅ Trades loaded from Kafka")
# Out:
# ✅ Trades loaded from Kafka

# %%
news_df = (spark.readStream
    .format("kafka")
    .options(**kafka_options)
    .option("subscribe", "news_topic")
    .load()
    .select(from_json(col("value").cast("string"), news_schema).alias("data"), "timestamp")
    .select("data.*", col("timestamp").alias("kafka_ts"))
    .withColumn("event_time", to_timestamp(col("published_at")))  # <- utilise published_at
    .withColumn("symbol", lit("BTCUSDT"))  # ou mettre dynamique selon besoin
    .withWatermark("event_time", "5 minutes")
)

print("✅ News stream OK")
# Out:
# ✅ News stream OK

# %%
joined_df = trades_df.alias("t").join(
    news_df.alias("n"),
    expr("""
        t.symbol = n.symbol AND
        t.event_time BETWEEN n.event_time - INTERVAL 24 HOURS
        AND n.event_time + INTERVAL 24 HOURS
    """),
    "left"
).select(
    col("t.symbol"),
    col("t.price"),
    col("t.quantity").alias("quantity"),  # <- corrige qty -> quantity
    col("t.event_time").alias("trade_time"),
    col("n.title").alias("news_title"),
    col("n.sentiment"),
    col("n.event_time").alias("news_time"),
    window(col("t.event_time"), "5 minutes").alias("window_5min")
)

print("✅ Join OK")
# Out:
# ✅ Join OK

# %%
query_lake = (joined_df.writeStream
    .format("delta")
    .outputMode("append")  # <-- append obligatoire
    .option("checkpointLocation", f"{CHECKPOINT_PATH}/lake")
    .option("path", DATA_PATH)
    .trigger(availableNow=True)
    .start()
)

query_lake.awaitTermination()
print("✅ Data written to Delta Lake")

# %%
# Lire les données enrichies depuis Delta Lake pour voir le résultat
df = spark.read.format("delta").load(DATA_PATH)
display(df.limit(50))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>symbol</th><th>price</th><th>quantity</th><th>trade_time</th><th>news_title</th><th>sentiment</th><th>news_time</th><th>window_5min</th></tr></thead><tbody><tr><td>BTCUSDT</td><td>66546.26</td><td>null</td><td>2026-02-25T14:23:21.130Z</td><td>null</td><td>null</td><td>null</td><td>List(2026-02-25T14:20:00.000Z, 2026-02-25T14:25:00.000Z)</td></tr><tr><td>BTCUSDT</td><td>66546.27</td><td>null</td><td>2026-02-25T14:23:21.313Z</td><td>null</td><td>null</
r><tr><td>BTCUSDT</td><td>66546.27</td><td>null</td><td>2026-02-25T14:23:24.204Z</td><td>null</td><td>null</td><td>null</td><td>List(2026-02-25T14:20:00.000Z, 2026-02-25T14:25:00.000Z)</td></tr><tr><td>BTCUSDT</td><td>66546.27</td><td>null</td><td>2026-02-25T14:23:24.209Z</td><td>null</td><td>null</td><td>null</td><td>List(2026-02-25T14:20:00.000Z, 2026-02-25T14:25:00.000Z)</td></tr><tr><td>BTCUSDT</td><td>66546.27</td><td>null</td><td>2026-02-25T14:23:24.209Z</td><td>null</td><td>null</td><td>null</td><td>List(2026-02-25T14:20:00.000Z, 2026-02-25T14:25:00.000Z)</td></tr><tr><td>BTCUSDT</td><td>66546.27</td><td>null</td><td>2026-02-25T14:23:24.209Z</td><td>null</td><td>null</td><td>null</td><td>List(2026-02-25T14:20:00.000Z, 2026-02-25T14:25:00.000Z)</td></tr><tr><td>BTCUSDT</td><td>66546.27</td><td>null</td><td>2026-02-25T14:23:24.209 ...

# %%
# Charger le Delta Lake
df = spark.read.format("delta").load("/Volumes/invistis/datalake/raw/enriched")

# Vérifier le schéma exact pour voir le nom de toutes les colonnes
df.printSchema()
# Out:
# root
#  |-- symbol: string (nullable = true)
#  |-- price: double (nullable = true)
#  |-- quantity: double (nullable = true)
#  |-- trade_time: timestamp (nullable = true)
#  |-- news_title: string (nullable = true)
#  |-- sentiment: double (nullable = true)
#  |-- news_time: timestamp (nullable = true)
#  |-- window_5min: struct (nullable = true)
#  |    |-- start: timestamp (nullable = true)
#  |    |-- end: timestamp (nullable = true)

# %%
# Afficher 20 lignes pour vérifier les valeurs
display(df.limit(20))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>symbol</th><th>price</th><th>quantity</th><th>trade_time</th><th>news_title</th><th>sentiment</th><th>news_time</th><th>window_5min</th></tr></thead><tbody><tr><td>BTCUSDT</td><td>66546.26</td><td>null</td><td>2026-02-25T14:23:21.130Z</td><td>null</td><td>null</td><td>null</td><td>List(2026-02-25T14:20:00.000Z, 2026-02-25T14:25:00.000Z)</td></tr><tr><td>BTCUSDT</td><td>66546.27</td><td>null</td><td>2026-02-25T14:23:21.313Z</td><td>null</td><td>null</td><td>null</td><td>List(2026-02-25T14:20:00.000Z, 2026-02-25T14:25:00.000Z)</td></tr><tr><td>BTCUSDT</td><td>66546.27</td><td>null</td><td>2026-02-25T14:23:21.359Z</td><td>null</td><td>null</td><td>null</td><td>List(2026-02-25T14:20:00.000Z, 2026-02-25T14:25:00.000Z)</td></tr><tr><td>BTCUSDT</td><td>66546.27</td><td>null</td><td>2026-02-25T14:23:21.423Z</td><td>null</td><td>null</td><td>null</td><td>List(2026-02-25T14:20:00.000Z, 2026-02-25T14:25:00.000Z)</td></tr><tr><td>BTCUSDT</td><td>66546.26</td><td>null</td><td>2026-02-25T14:23:21.534Z</td><td>null</td><td>null</td><td>null</td><td>List(2026-02-25T14:20:00.000Z, 2026-02-25T14:25:00.000Z)</td></tr><tr><td>BTCUSDT</td><td>66546.26</td><td>null</td><td>2026-02-25T14:23:22.296Z</td><td>null
# %%
# Schéma des trades
trades_schema = StructType([
    StructField("symbol", StringType()),
    StructField("price", DoubleType()),
    StructField("quantity", DoubleType()), 
    StructField("timestamp", LongType()),
    StructField("trade_id", StringType())
])

# Schéma des news
news_schema = StructType([
    StructField("title", StringType()),
    StructField("description", StringType()),
    StructField("source", StringType()),
    StructField("published_at", StringType()),
    StructField("sentiment", DoubleType())
])

# %%
trades_df = (spark.read
    .format("kafka")
    .options(**kafka_options)
    .option("subscribe", "trades_topic")
    .option("startingOffsets", "earliest")
    .load()
    .select(from_json(col("value").cast("string"), trades_schema).alias("data"))
    .select("data.*")
    .withColumn("event_time", to_timestamp(col("timestamp") / 1000))
)

print("✅ Trades loaded from Kafka")
trades_df.show(20, truncate=False)
# Out:
# ✅ Trades loaded from Kafka
# +-------+-------+--------+-------------+--------+-----------------------+
# |symbol |price  |quantity|timestamp    |trade_id|event_time             |
# +-------+-------+--------+-------------+--------+-----------------------+
# |ETHUSDT|1825.7 |0.0023  |1771935088791|NULL    |2026-02-24 12:11:28.791|
# |ETHUSDT|1825.7 |0.0029  |1771935088791|NULL    |2026-02-24 12:11:28.791|
# |ETHUSDT|1825.7 |0.0854  |1771935088791|NULL    |2026-02-24 12:11:28.791|
# |BTCUSDT|63224.1|2.0E-4  |1771935088796|NULL    |2026-02-24 12:11:28.796|
# |SOLUSDT|76.78  |0.067   |1771935089396|NULL    |2026-02-24 12:11:29.396|
# |BNBUSDT|586.86 |0.009   |1771935089408|NULL    |2026-02-24 12:11:29.408|
# |BNBUSDT|586.86 |0.009   |1771935089408|NULL    |2026-02-24 12:11:29.408|
# |BNBUSDT|586.86 |0.009   |1771935089408|NULL    |2026-02-24 12:11:29.408|
# |BNBUSDT|586.86 |0.009   |1771935089408|NULL    |2026-02-24 12:11:29.408|
# |BNBUSDT|586.85 |0.009   |1771935089408|NULL    |2026-02-24 12:11:29.408|
# |BNBUSDT|586.84 |0.009   |1771935089408|NULL    |2026-02-24 12:11:29.408|
# |BNBUSDT|586.84 |0.009   |1771935089408|NULL    |2026-02-24 12:11:29.408|
# |BNBUSDT|586.82 |1.339   |1771935089602|NULL    |2026-02-24 12:11:29.602|
# |BTCUSDT|63224.1|1.7E-4  |1771935089935|NULL    |2026-02-24 12:11:29.935|
# |BTCUSDT|63224.1|0.00326 |1771935089935|NULL    |2026-02-24 12:11:29.935|
# |BTCUSDT|63224.1|0.02086 |1771935089935|NULL    |2026-02-24 12:11:29.935|
# |SOLUSDT|76.77  |0.095   |1771935090528|NULL    |2026-02-24 12:11:30.528|
# |SOLUSDT|76.77  |0.419   |1771935090528|NULL    |2026-02-24 12:11:30.528|
# |BTCUSDT|63224.1|1.7E-4  |1771935091727|NULL    |2026-02-24 12:11:31.727|
# |BTCUSDT|63224.1|8.0E-5  |1771935091727|NULL    |2026-02-24 12:11:31.727|
# +-------+-------+--------+-------------+--------+-----------------------+
# only showing top 20 rows
